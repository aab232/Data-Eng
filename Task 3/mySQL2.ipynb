# %%
import mysql.connector
import pandas as pd
from tabulate import tabulate
import time  # For measuring query execution time

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Aliza.123",
    database="bookstore_db"
)

cursor = conn.cursor(buffered=True)

# Ensure the Publication Date column exists in books table
cursor.execute("SHOW COLUMNS FROM books LIKE 'PublicationDate'")
if not cursor.fetchone():
    cursor.execute("ALTER TABLE books ADD COLUMN PublicationDate VARCHAR(50)")
    conn.commit()
    print("✅ Added missing column: PublicationDate")

# Load book data
df = pd.read_csv("amazon_data_engineering_books.csv")

# Trim whitespace in column names (Fixes potential mismatch)
df.columns = df.columns.str.strip()

# Get the correct column name for publication date
publication_date_column = "Publication Date"  # Ensure this matches exactly

# Insert data while preventing duplicates
for index, row in df.iterrows():
    if pd.notnull(row['Title']) and pd.notnull(row['Author']) and pd.notnull(row['Rating']) and pd.notnull(row['Price']) and pd.notnull(row[publication_date_column]):
        # Insert Author if not exists
        cursor.execute("SELECT AuthorID FROM authors WHERE AuthorName = %s", (row['Author'],))
        author = cursor.fetchone()
        if not author:
            cursor.execute("INSERT INTO authors (AuthorName) VALUES (%s)", (row['Author'],))
            conn.commit()
            cursor.execute("SELECT AuthorID FROM authors WHERE AuthorName = %s", (row['Author'],))
            author_id = cursor.fetchone()[0]
        else:
            author_id = author[0]

        # Insert Book with Publication Date, ensuring it is updated if missing
        cursor.execute("SELECT BookID, PublicationDate FROM books WHERE Title = %s", (row['Title'],))
        book = cursor.fetchone()
        
        if not book:
            cursor.execute("""
                INSERT INTO books (Title, PublicationDate)
                VALUES (%s, %s)
                ON DUPLICATE KEY UPDATE PublicationDate = VALUES(PublicationDate);
            """, (row['Title'], row[publication_date_column]))
            conn.commit()
            cursor.execute("SELECT BookID FROM books WHERE Title = %s", (row['Title'],))
            book_id = cursor.fetchone()[0]
        else:
            book_id, existing_pub_date = book
            # Update if publication date is missing
            if existing_pub_date is None:
                cursor.execute("""
                    UPDATE books SET PublicationDate = %s WHERE BookID = %s;
                """, (row[publication_date_column], book_id))
                conn.commit()

        # Prevent duplicate bookstore entries
        cursor.execute("""
            SELECT StoreID FROM bookstore WHERE BookID = %s AND AuthorID = %s;
        """, (book_id, author_id))
        if cursor.fetchone() is None:
            cursor.execute("""
                INSERT INTO bookstore (BookID, AuthorID, Price, Rating)
                VALUES (%s, %s, %s, %s);
            """, (book_id, author_id, row['Price'], row['Rating']))
            conn.commit()

print("✅ Data successfully updated in MySQL!")

# Query books with Publication Date
query = """
    SELECT authors.AuthorName, books.Title, books.PublicationDate, bookstore.Rating, bookstore.Price
    FROM bookstore
    JOIN books ON bookstore.BookID = books.BookID
    JOIN authors ON bookstore.AuthorID = authors.AuthorID
    ORDER BY bookstore.Rating DESC;
"""

# Start the timer before running the query
start_time = time.time()

# Execute the query
cursor.execute(query)
results = cursor.fetchall()

# Calculate execution time
execution_time = time.time() - start_time

# Convert to DataFrame
df_results = pd.DataFrame(results, columns=["Author", "Title", "Publication Date", "Rating", "Price"])

# Display execution time
print(f"📌 MySQL Query Execution Time: {execution_time:.5f} seconds")

# Display updated results
print(tabulate(df_results, headers='keys', tablefmt='psql'))

# Close connections
cursor.close()
conn.close()
# Out:
# ✅ Data successfully updated in MySQL!
# 📌 MySQL Query Execution Time: 0.00074 seconds
# +-----+----------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+----------+---------+
# |     | Author                                                                           | Title                                                                                                                                                                              | Publication Date   |   Rating |   Price |
# |-----+----------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+----------+---------|
# |   0 | Tamer Khraisha                                                                   | "Financial Data Engineering: Design and Build Data-Driven Financial Products"                                                                                                      | November 12, 2024  |      5   |      60 |
# |   1 | Tamer Khraisha                                                                   | "Financial Data Engineering: Design and Build Data-Driven Financial Products"                                                                                                      | November 12, 2024  |      5   |      60 |
# |   2 | Tamer Khraisha                                                                   | "Financial Data Engineering: Design and Build Data-Driven Financial Products"                                                                                                      | November 12, 2024  |      5   |      60 |
# |   3 | Tamer Khraisha                                                                   | "Financial Data Engineering: Design and Build Data-Driven Financial Products"                                                                                                      | November 12, 2024  |      5   |      60 |
# |   4 | Tamer Khraisha                                                                   | "Financial Data Engineering: Design and Build Data-Driven Financial Products"                                                                                                      | November 12, 2024  |      5   |      60 |
# |   5 | Richard J. Schiller, David Larochelle                                            | "Data Engineering Best Practices: Architect robust and cost-effective data solutions in the cloud era"                                                                             | October 11, 2024   |      5   |      39 |
# |   6 | Richard J. Schiller, David Larochelle                                            | "Data Engineering Best Practices: Architect robust and cost-effective data solutions in the cloud era"                                                                             | October 11, 2024   |      5   |      39 |
# |   7 | Richard J. Schiller, David Larochelle                                            | "Data Engineering Best Practices: Architect robust and cost-effective data solutions in the cloud era"                                                                             | October 11, 2024   |      5   |      39 |
# |   8 | Richard J. Schiller, David Larochelle                                            | "Data Engineering Best Practices: Architect robust and cost-effective data solutions in the cloud era"                                                                             | October 11, 2024   |      5   |      39 |
# |   9 | Richard J. Schiller, David Larochelle                                            | "Data Engineering Best Practices: Architect robust and cost-effective data solutions in the cloud era"                                                                             | October 11, 2024   |      5   |      39 |
# |  10 | Trâm Ngọc Phạm, Gonzalo Herreros González                                        | "Data Engineering with AWS Cookbook: A recipe-based approach to help you tackle data engineering problems with AWS services"                                                       | November 29, 2024  |      5   |      49 |
# |  11 | Trâm Ngọc Phạm, Gonzalo Herreros González                                        | "Data Engineering with AWS Cookbook: A recipe-based approach to help you tackle data engineering problems with AWS services"                                                       | November 29, 2024  |      5   |      49 |
# |  12 | Trâm Ngọc Phạm, Gonzalo Herreros González                                        | "Data Engineering with AWS Cookbook: A recipe-based approach to help you tackle data engineering problems with AWS services"                                                       | November 29, 2024  |      5   |      49 |
# |  13 | Trâm Ngọc Phạm, Gonzalo Herreros González                                        | "Data Engineering with AWS Cookbook: A recipe-based approach to help you tackle data engineering problems with AWS services"                                                       | November 29, 2024  |      5   |      49 |
# |  14 | Trâm Ngọc Phạm, Gonzalo Herreros González                                        | "Data Engineering with AWS Cookbook: A recipe-based approach to help you tackle data engineering problems with AWS services"                                                       | November 29, 2024  |      5   |      49 |
# |  15 | Book 1 of 4: Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More | "Python Data Engineering Resources: Forge Your Path to Success in Data Engineering, Machine Learning and AI (Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More)" | September 27, 2024 |      4.9 |       9 |
# |  16 | Book 1 of 4: Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More | "Python Data Engineering Resources: Forge Your Path to Success in Data Engineering, Machine Learning and AI (Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More)" | September 27, 2024 |      4.9 |       9 |
# |  17 | Book 1 of 4: Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More | "Python Data Engineering Resources: Forge Your Path to Success in Data Engineering, Machine Learning and AI (Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More)" | September 27, 2024 |      4.9 |       9 |
# |  18 | Book 1 of 4: Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More | "Python Data Engineering Resources: Forge Your Path to Success in Data Engineering, Machine Learning and AI (Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More)" | September 27, 2024 |      4.9 |       9 |
# |  19 | Book 1 of 4: Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More | "Python Data Engineering Resources: Forge Your Path to Success in Data Engineering, Machine Learning and AI (Future-Proof Tech Skills: Including AI, Python, SQL, Linux And More)" | September 27, 2024 |      4.9 |       9 |
# |  20 | Martin Kleppmann                                                                 | "Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems"                                                                         | April 2, 2017      |      4.8 |      47 |
# |  21 | Martin Kleppmann                                                                 | "Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems"                                                                         | April 2, 2017      |      4.8 |      47 |
# |  22 | Martin Kleppmann                                                                 | "Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems"                                                                         | April 2, 2017      |      4.8 |      47 |
# |  23 | Martin Kleppmann                                                                 | "Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems"                                                                         | April 2, 2017      |      4.8 |      47 |
# |  24 | Martin Kleppmann                                                                 | "Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems"                                                                         | April 2, 2017      |      4.8 |      47 |
# |  25 | Steven L. Brunton, J. Nathan Kutz                                                | "Data-Driven Science and Engineering: Machine Learning, Dynamical Systems, and Control"                                                                                            | July 28, 2022      |      4.8 |      60 |
# |  26 | Steven L. Brunton, J. Nathan Kutz                                                | "Data-Driven Science and Engineering: Machine Learning, Dynamical Systems, and Control"                                                                                            | July 28, 2022      |      4.8 |      60 |
# |  27 | Steven L. Brunton, J. Nathan Kutz                                                | "Data-Driven Science and Engineering: Machine Learning, Dynamical Systems, and Control"                                                                                            | July 28, 2022      |      4.8 |      60 |
# |  28 | Steven L. Brunton, J. Nathan Kutz                                                | "Data-Driven Science and Engineering: Machine Learning, Dynamical Systems, and Control"                                                                                            | July 28, 2022      |      4.8 |      60 |
# |  29 | Steven L. Brunton, J. Nathan Kutz                                                | "Data-Driven Science and Engineering: Machine Learning, Dynamical Systems, and Control"                                                                                            | July 28, 2022      |      4.8 |      60 |
# |  30 | Joe Reis, Matt Housley                                                           | "Fundamentals of Data Engineering: Plan and Build Robust Data Systems"                                                                                                             | July 26, 2022      |      4.7 |      43 |
# |  31 | Joe Reis, Matt Housley                                                           | "Fundamentals of Data Engineering: Plan and Build Robust Data Systems"                                                                                                             | July 26, 2022      |      4.7 |      43 |
# |  32 | Joe Reis, Matt Housley                                                           | "Fundamentals of Data Engineering: Plan and Build Robust Data Systems"                                                                                                             | July 26, 2022      |      4.7 |      43 |
# |  33 | Joe Reis, Matt Housley                                                           | "Fundamentals of Data Engineering: Plan and Build Robust Data Systems"                                                                                                             | July 26, 2022      |      4.7 |      43 |
# |  34 | Joe Reis, Matt Housley                                                           | "Fundamentals of Data Engineering: Plan and Build Robust Data Systems"                                                                                                             | July 26, 2022      |      4.7 |      43 |
# |  35 | François Voron                                                                   | "Building Data Science Applications with FastAPI - Second Edition: Develop, manage, and deploy efficient machine learning applications with Python"                                | July 31, 2023      |      4.7 |      47 |
# |  36 | François Voron                                                                   | "Building Data Science Applications with FastAPI - Second Edition: Develop, manage, and deploy efficient machine learning applications with Python"                                | July 31, 2023      |      4.7 |      47 |
# |  37 | François Voron                                                                   | "Building Data Science Applications with FastAPI - Second Edition: Develop, manage, and deploy efficient machine learning applications with Python"                                | July 31, 2023      |      4.7 |      47 |
# |  38 | François Voron                                                                   | "Building Data Science Applications with FastAPI - Second Edition: Develop, manage, and deploy efficient machine learning applications with Python"                                | July 31, 2023      |      4.7 |      47 |
# |  39 | François Voron                                                                   | "Building Data Science Applications with FastAPI - Second Edition: Develop, manage, and deploy efficient machine learning applications with Python"                                | July 31, 2023      |      4.7 |      47 |
# |  40 | Maja Ferle                                                                       | "Snowflake Data Engineering"                                                                                                                                                       | January 28, 2025   |      4.7 |      49 |
# |  41 | Maja Ferle                                                                       | "Snowflake Data Engineering"                                                                                                                                                       | January 28, 2025   |      4.7 |      49 |
# |  42 | Maja Ferle                                                                       | "Snowflake Data Engineering"                                                                                                                                                       | January 28, 2025   |      4.7 |      49 |
# |  43 | Maja Ferle                                                                       | "Snowflake Data Engineering"                                                                                                                                                       | January 28, 2025   |      4.7 |      49 |
# |  44 | Maja Ferle                                                                       | "Snowflake Data Engineering"                                                                                                                                                       | January 28, 2025   |      4.7 |      49 |
# |  45 | Book 3 of 3: The Innovators of AI and Data Series                                | "Data Engineering Excellence: Architecting Resilient Systems from Scratch to Scale (The Innovators of AI and Data Series Book 3)"                                                  | February 24, 2025  |      4.7 |       0 |
# |  46 | Book 3 of 3: The Innovators of AI and Data Series                                | "Data Engineering Excellence: Architecting Resilient Systems from Scratch to Scale (The Innovators of AI and Data Series Book 3)"                                                  | February 24, 2025  |      4.7 |       0 |
# |  47 | Book 3 of 3: The Innovators of AI and Data Series                                | "Data Engineering Excellence: Architecting Resilient Systems from Scratch to Scale (The Innovators of AI and Data Series Book 3)"                                                  | February 24, 2025  |      4.7 |       0 |
# |  48 | Book 3 of 3: The Innovators of AI and Data Series                                | "Data Engineering Excellence: Architecting Resilient Systems from Scratch to Scale (The Innovators of AI and Data Series Book 3)"                                                  | February 24, 2025  |      4.7 |       0 |
# |  49 | Book 3 of 3: The Innovators of AI and Data Series                                | "Data Engineering Excellence: Architecting Resilient Systems from Scratch to Scale (The Innovators of AI and Data Series Book 3)"                                                  | February 24, 2025  |      4.7 |       0 |
# |  50 | Roberto Zagni                                                                    | "Data Engineering with dbt: A practical guide to building a cloud-based, pragmatic, and dependable data platform with SQL"                                                         | June 30, 2023      |      4.7 |      37 |
# |  51 | Roberto Zagni                                                                    | "Data Engineering with dbt: A practical guide to building a cloud-based, pragmatic, and dependable data platform with SQL"                                                         | June 30, 2023      |      4.7 |      37 |
# |  52 | Roberto Zagni                                                                    | "Data Engineering with dbt: A practical guide to building a cloud-based, pragmatic, and dependable data platform with SQL"                                                         | June 30, 2023      |      4.7 |      37 |
# |  53 | Roberto Zagni                                                                    | "Data Engineering with dbt: A practical guide to building a cloud-based, pragmatic, and dependable data platform with SQL"                                                         | June 30, 2023      |      4.7 |      37 |
# |  54 | Roberto Zagni                                                                    | "Data Engineering with dbt: A practical guide to building a cloud-based, pragmatic, and dependable data platform with SQL"                                                         | June 30, 2023      |      4.7 |      37 |
# |  55 | Chip Huyen                                                                       | "AI Engineering: Building Applications with Foundation Models"                                                                                                                     | January 7, 2025    |      4.6 |      68 |
# |  56 | Chip Huyen                                                                       | "AI Engineering: Building Applications with Foundation Models"                                                                                                                     | January 7, 2025    |      4.6 |      68 |
# |  57 | Chip Huyen                                                                       | "AI Engineering: Building Applications with Foundation Models"                                                                                                                     | January 7, 2025    |      4.6 |      68 |
# |  58 | Chip Huyen                                                                       | "AI Engineering: Building Applications with Foundation Models"                                                                                                                     | January 7, 2025    |      4.6 |      68 |
# |  59 | Chip Huyen                                                                       | "AI Engineering: Building Applications with Foundation Models"                                                                                                                     | January 7, 2025    |      4.6 |      68 |
# |  60 | James Densmore                                                                   | "Data Pipelines Pocket Reference: Moving and Processing Data for Analytics"                                                                                                        | March 16, 2021     |      4.6 |      17 |
# |  61 | James Densmore                                                                   | "Data Pipelines Pocket Reference: Moving and Processing Data for Analytics"                                                                                                        | March 16, 2021     |      4.6 |      17 |
# |  62 | James Densmore                                                                   | "Data Pipelines Pocket Reference: Moving and Processing Data for Analytics"                                                                                                        | March 16, 2021     |      4.6 |      17 |
# |  63 | James Densmore                                                                   | "Data Pipelines Pocket Reference: Moving and Processing Data for Analytics"                                                                                                        | March 16, 2021     |      4.6 |      17 |
# |  64 | James Densmore                                                                   | "Data Pipelines Pocket Reference: Moving and Processing Data for Analytics"                                                                                                        | March 16, 2021     |      4.6 |      17 |
# |  65 | Cole Nussbaumer Knaflic                                                          | "Storytelling with Data: A Data Visualization Guide for Business Professionals"                                                                                                    | November 2, 2015   |      4.6 |      21 |
# |  66 | Cole Nussbaumer Knaflic                                                          | "Storytelling with Data: A Data Visualization Guide for Business Professionals"                                                                                                    | November 2, 2015   |      4.6 |      21 |
# |  67 | Cole Nussbaumer Knaflic                                                          | "Storytelling with Data: A Data Visualization Guide for Business Professionals"                                                                                                    | November 2, 2015   |      4.6 |      21 |
# |  68 | Cole Nussbaumer Knaflic                                                          | "Storytelling with Data: A Data Visualization Guide for Business Professionals"                                                                                                    | November 2, 2015   |      4.6 |      21 |
# |  69 | Cole Nussbaumer Knaflic                                                          | "Storytelling with Data: A Data Visualization Guide for Business Professionals"                                                                                                    | November 2, 2015   |      4.6 |      21 |
# |  70 | Vijaya Kumar Suda                                                                | "Data Labeling in Machine Learning with Python: Explore modern ways to prepare labeled data for training and fine-tuning ML and generative AI models"                              | February 9, 2024   |      4.6 |      44 |
# |  71 | Vijaya Kumar Suda                                                                | "Data Labeling in Machine Learning with Python: Explore modern ways to prepare labeled data for training and fine-tuning ML and generative AI models"                              | February 9, 2024   |      4.6 |      44 |
# |  72 | Vijaya Kumar Suda                                                                | "Data Labeling in Machine Learning with Python: Explore modern ways to prepare labeled data for training and fine-tuning ML and generative AI models"                              | February 9, 2024   |      4.6 |      44 |
# |  73 | Vijaya Kumar Suda                                                                | "Data Labeling in Machine Learning with Python: Explore modern ways to prepare labeled data for training and fine-tuning ML and generative AI models"                              | February 9, 2024   |      4.6 |      44 |
# |  74 | Vijaya Kumar Suda                                                                | "Data Labeling in Machine Learning with Python: Explore modern ways to prepare labeled data for training and fine-tuning ML and generative AI models"                              | February 9, 2024   |      4.6 |      44 |
# |  75 | Vlad Riscutia                                                                    | "Data Engineering on Azure"                                                                                                                                                        | August 17, 2021    |      4.5 |      43 |
# |  76 | Vlad Riscutia                                                                    | "Data Engineering on Azure"                                                                                                                                                        | August 17, 2021    |      4.5 |      43 |
# |  77 | Vlad Riscutia                                                                    | "Data Engineering on Azure"                                                                                                                                                        | August 17, 2021    |      4.5 |      43 |
# |  78 | Vlad Riscutia                                                                    | "Data Engineering on Azure"                                                                                                                                                        | August 17, 2021    |      4.5 |      43 |
# |  79 | Vlad Riscutia                                                                    | "Data Engineering on Azure"                                                                                                                                                        | August 17, 2021    |      4.5 |      43 |
# |  80 | Pulkit Chadha                                                                    | "Data Engineering with Databricks Cookbook: Build effective data and AI solutions using Apache Spark, Databricks, and Delta Lake"                                                  | May 31, 2024       |      4.4 |      39 |
# |  81 | Pulkit Chadha                                                                    | "Data Engineering with Databricks Cookbook: Build effective data and AI solutions using Apache Spark, Databricks, and Delta Lake"                                                  | May 31, 2024       |      4.4 |      39 |
# |  82 | Pulkit Chadha                                                                    | "Data Engineering with Databricks Cookbook: Build effective data and AI solutions using Apache Spark, Databricks, and Delta Lake"                                                  | May 31, 2024       |      4.4 |      39 |
# |  83 | Pulkit Chadha                                                                    | "Data Engineering with Databricks Cookbook: Build effective data and AI solutions using Apache Spark, Databricks, and Delta Lake"                                                  | May 31, 2024       |      4.4 |      39 |
# |  84 | Pulkit Chadha                                                                    | "Data Engineering with Databricks Cookbook: Build effective data and AI solutions using Apache Spark, Databricks, and Delta Lake"                                                  | May 31, 2024       |      4.4 |      39 |
# |  85 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  86 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  87 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  88 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  89 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  90 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  91 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  92 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  93 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  94 | Gareth Eagar                                                                     | "Data Engineering with AWS: Acquire the skills to design and build AWS-based data transformation pipelines like a pro"                                                             | October 31, 2023   |      4.3 |      24 |
# |  95 | Paul Houghton                                                                    | "Data Engineering with Alteryx: Helping data engineers apply DataOps practices with Alteryx"                                                                                       | June 30, 2022      |      4.3 |      31 |
# |  96 | Paul Houghton                                                                    | "Data Engineering with Alteryx: Helping data engineers apply DataOps practices with Alteryx"                                                                                       | June 30, 2022      |      4.3 |      31 |
# |  97 | Paul Houghton                                                                    | "Data Engineering with Alteryx: Helping data engineers apply DataOps practices with Alteryx"                                                                                       | June 30, 2022      |      4.3 |      31 |
# |  98 | Paul Houghton                                                                    | "Data Engineering with Alteryx: Helping data engineers apply DataOps practices with Alteryx"                                                                                       | June 30, 2022      |      4.3 |      31 |
# |  99 | Paul Houghton                                                                    | "Data Engineering with Alteryx: Helping data engineers apply DataOps practices with Alteryx"                                                                                       | June 30, 2022      |      4.3 |      31 |
# | 100 | Paul Crickard                                                                    | "Data Engineering with Python: Work with massive datasets to design data models and automate data pipelines using Python"                                                          | October 23, 2020   |      4.1 |      37 |
# | 101 | Paul Crickard                                                                    | "Data Engineering with Python: Work with massive datasets to design data models and automate data pipelines using Python"                                                          | October 23, 2020   |      4.1 |      37 |
# | 102 | Paul Crickard                                                                    | "Data Engineering with Python: Work with massive datasets to design data models and automate data pipelines using Python"                                                          | October 23, 2020   |      4.1 |      37 |
# | 103 | Paul Crickard                                                                    | "Data Engineering with Python: Work with massive datasets to design data models and automate data pipelines using Python"                                                          | October 23, 2020   |      4.1 |      37 |
# | 104 | Paul Crickard                                                                    | "Data Engineering with Python: Work with massive datasets to design data models and automate data pipelines using Python"                                                          | October 23, 2020   |      4.1 |      37 |
# | 105 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 106 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 107 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 108 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 109 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 110 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 111 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 112 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 113 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# | 114 | Kedeisha Bryan                                                                   | "Cracking the Data Engineering Interview: Land your dream job with the help of resume-building tips, over 100 mock questions, and a unique portfolio"                              | November 7, 2023   |      4   |      26 |
# +-----+----------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+----------+---------+
